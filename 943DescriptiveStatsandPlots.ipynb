# %%
#Data Exploration and Visualization of Forecast Accuracy in Stock Predictions

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load CSV data from URL
url = "https://drive.google.com/uc?id=15akNjGB2rSjQwz7sXsWevZk0xDqarNja"
data = pd.read_csv(url, encoding="utf-8").dropna()

# Save data to Excel
data.to_excel("forecast_data.xlsx", index=False)



# Load Excel data
data = pd.read_excel("forecast_data.xlsx")

# Display first few rows
print(data.head())

# Descriptive statistics
print("\nDescriptive Statistics:\n", data.describe(include='all'))

# Class distribution
print('\nBalance of positive and negative error classes (%): \n',
      data['stock_error'].value_counts(normalize=True) * 100)

# Plot forecast-related columns (assuming columns named with 'forecast')
forecast_cols = [col for col in data.columns if 'forecast' in col.lower()]

# Pairplot to visualize forecast columns
if forecast_cols:
    sns.pairplot(data, vars=forecast_cols, hue='stock_error')
    plt.suptitle('Pairplot of Forecast Columns by Stock Error', y=1.02)
    plt.show()
else:
    print("No forecast-related columns found.")
# Out:
#    book_stock_0  case_size  case_weight  store_life     price      freq  \
# 0      0.309124   0.066787     0.000000    0.332521  0.058882  0.081851
# 1      0.353862   0.110186     0.014141    0.183649  0.241486  0.250265
# 2      0.317169   0.043406     0.000000    0.003590  0.893731  0.079222
# 3      0.432924   0.059134     0.023364    0.054174  0.132523  0.697323
# 4      0.282390   0.001063     0.013094    0.001263  0.544779  0.000000
#
#    rem_life  last_count_1  scan_freq  shelf_cap  ...  book_stock_2    counts  \
# 0  0.306519      0.093523   0.450998   0.078236  ...      0.478851  0.102392
# 1  0.193292      0.247673   0.000000   0.081874  ...      0.485379  0.031260
# 2  0.987711      0.543073   0.232471   0.052502  ...      0.474031  0.063054
# 3  0.101725      0.579191   0.000000   0.161566  ...      0.521249  0.000000
# 4  0.053647      0.450560   0.042113   0.012922  ...      0.453709  0.040997
#
#      change  rejection  SKU_l1  SKU_l2  SKU_l3  fresh  size  stock_error
# 0  1.002154   0.003920       G      G1     G16      0     L            1
# 1  0.997516   0.008149       G      G5     G51      0     L            1
# 2  1.006205   0.000000       N      N5     N56     -1     M            1
# 3  0.000000   0.003920       W      W3     W31      0     M            1
# 4  0.002671   0.001235       F      F5     F55      1     M            0
#
# [5 rows x 28 columns]
#
# Descriptive Statistics:
#           book_stock_0      case_size    case_weight     store_life  \
# count   367937.000000  367937.000000  367937.000000  367937.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean         0.346815       0.108129       0.008789       0.137768
# std          0.081246       0.095307       0.032909       0.173959
# min          0.000000       0.000000       0.000000       0.000000
# 25%          0.294712       0.055534       0.000472       0.004584
# 50%          0.323251       0.081807       0.004932       0.087797
# 75%          0.371218       0.146541       0.010400       0.214986
# max          1.000406       1.007145       1.004035       1.006144
#
#                 price           freq       rem_life   last_count_1  \
# count   367937.000000  367937.000000  367937.000000  367937.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean         0.187707       0.205498       0.295581       0.298139
# std          0.182570       0.230388       0.329242       0.246130
# min          0.000000       0.000000       0.000000       0.000000
# 25%          0.052436       0.031151       0.060587       0.075758
# 50%          0.145428       0.119387       0.159117       0.233554
# 75%          0.264229       0.302895       0.340274       0.526608
# max          1.000000       1.016053       1.017253       1.011473
#
#             scan_freq      shelf_cap  ...   book_stock_2         counts  \
# count   367937.000000  367937.000000  ...  367937.000000  367937.000000
# unique            NaN            NaN  ...            NaN            NaN
# top               NaN            NaN  ...            NaN            NaN
# freq              NaN            NaN  ...            NaN            NaN
# mean         0.137757       0.131311  ...       0.494900       0.124988
# std          0.213441       0.131048  ...       0.036485       0.155062
# min          0.000000       0.000000  ...       0.000799       0.000000
# 25%          0.000000       0.049395  ...       0.472561       0.030325
# 50%          0.050994       0.088338  ...       0.485221       0.070836
# 75%          0.176206       0.162639  ...       0.505492       0.169716
# max          1.000000       1.010337  ...       1.004606       1.011805
#
#                change      rejection  SKU_l1  SKU_l2  SKU_l3          fresh  \
# count   367937.000000  367937.000000  367937  367937  367937  367937.000000
# unique            NaN            NaN       5      23      77            NaN
# top               NaN            NaN       G      N5     N56            NaN
# freq              NaN            NaN  139603   96249   38752            NaN
# mean         0.440340       0.021833     NaN     NaN     NaN      -0.094307
# std          0.399002       0.108922     NaN     NaN     NaN       0.645287
# min          0.000000       0.000000     NaN     NaN     NaN      -1.000000
# 25%          0.002816       0.000000     NaN     NaN     NaN      -1.000000
# 50%          0.421444       0.000827     NaN     NaN     NaN       0.000000
# 75%          0.835767       0.005008     NaN     NaN     NaN       0.000000
# max          1.020508       1.011795     NaN     NaN     NaN       1.000000
#
#           size    stock_error
# count   367937  367937.000000
# unique       3            NaN
# top          M            NaN
# freq    222185            NaN
# mean       NaN       0.535162
# std        NaN       0.498763
# min        NaN       0.000000
# 25%        NaN       0.000000
# 50%        NaN       1.000000
# 75%        NaN       1.000000
# max        NaN       1.000000
#
# [11 rows x 28 columns]
#
# Balance of positive and negative error classes (%):
#  stock_error
# 1    53.516227
# 0    46.483773
# Name: proportion, dtype: float64
